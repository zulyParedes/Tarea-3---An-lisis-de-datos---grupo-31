# %%
#1.Realizar un análisis exploratorio de los datos para identificar relaciones entre variables, valores atípicos, tendencias, etc.

# %%
#cargue de librerias
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report,confusion_matrix

# %%
# Lectura y cargado de datos

datos= pd.read_csv('C:/Users/VIVIS/OneDrive/Documentos/PYTHON/Car_details_v3.csv')

# %%
# Lectura de dato para el analisis exploratorio
datos.head(50)
# Out:
#                                                  name    year  selling_price  \
# 0                              Maruti Swift Dzire VDI  2014.0       450000.0
# 1                        Skoda Rapid 1.5 TDI Ambition  2014.0       370000.0
# 2   Honda City 2017-2020 EXi,2006,158000,140000,Pe...     NaN            NaN
# 3                           Hyundai i20 Sportz Diesel  2010.0       225000.0
# 4   Maruti Swift VXI BSIII,2007,130000,120000,Petr...     NaN            NaN
# 5                       Hyundai Xcent 1.2 VTVT E Plus  2017.0       440000.0
# 6   Maruti Wagon R LXI DUO BSIII,2007,96000,175000...     NaN            NaN
# 7                                  Maruti 800 DX BSII  2001.0        45000.0
# 8                                    Toyota Etios VXD  2011.0       350000.0
# 9                Ford Figo Diesel Celebration Edition  2013.0       200000.0
# 10                    Renault Duster 110PS Diesel RxL  2014.0       500000.0
# ...

# %%
datos.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  7787.000000   7.787000e+03  7.787000e+03  7566.000000
# mean   2014.054193   6.566975e+05  6.840663e+04     5.422284
# std       3.911379   8.174188e+05  5.663441e+04     0.955162
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2012.000000   2.750000e+05  3.300150e+04     5.000000
# 50%    2015.000000   4.599990e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.965000e+05  9.000000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
# identificación datos faltantes y atipicos en la casilla de años

plt.figure(figsize=(8, 4))
sns.boxplot(x=datos['year'])
plt.title('Datos faltantes y atipicos año', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Datos faltantes y atipicos año')

# %%
# identificación datos faltantes y atipicos en la casilla de precio de venta

plt.figure(figsize=(8, 4))
sns.boxplot(x=datos['selling_price'])
plt.title('Datos faltantes y atipicos precio de venta', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Datos faltantes y atipicos precio de venta')

# %%
# identificación datos faltantes y atipicos en la casilla de kilometros recorridos

plt.figure(figsize=(8, 4))
sns.boxplot(x=datos['km_driven'])
plt.title('Datos faltantes y atipicos kilometros recorridos', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Datos faltantes y atipicos kilometros recorridos')

# %%
# identificación datos faltantes y atipicos en la casilla de cantidad de asientos

plt.figure(figsize=(8, 4))
sns.boxplot(x=datos['seats'])
plt.title('Datos faltantes y atipicos asientos', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Datos faltantes y atipicos asientos')

# %%
#2.Preprocesar los datos limpiándolos, tratando valores faltantes y transformándolos según sea necesario.

# %%
# Comprobando valores nulos
datos.isnull().sum()*100/datos.shape[0]
# Out:
# name             0.000000
# year             4.195374
# selling_price    4.195374
# km_driven        4.195374
# fuel             4.195374
# seller_type      4.195374
# transmission     4.195374
# owner            4.195374
# mileage          6.914370
# engine           6.914370
# max_power        6.840551
# torque           6.926673
# seats            6.914370
# dtype: float64

# %%
# Revisión datos faltantes

print("Cantidad de registros con valores en 0 en Asientos: ",datos['seats'].isin ([0]).sum())
print("Cantidad de registros con valores en 0 en Precio de venta: ",datos['selling_price'].isin ([0]).sum())
print("Cantidad de registros con valores en 0 en Años: ",datos['year'].isin ([0]).sum())
# Out:
# Cantidad de registros con valores en 0 en Asientos:  0
# Cantidad de registros con valores en 0 en Precio de venta:  0
# Cantidad de registros con valores en 0 en Años:  0

# %%
# conteo de datos atipicos year

nivel_minimo =1950
nivel_maximo =2020
total_atipicos=((datos['year']<nivel_minimo)|(datos['year']<nivel_maximo)).sum()
print("el total de datos atipicos en cuanto al modelo de los coches es {}".format(total_atipicos))
# Out:
# el total de datos atipicos en cuanto al modelo de los coches es 7713

# %%
# identificación datos faltantes y atipicos en la casilla de años

plt.figure(figsize=(8, 4))
sns.boxplot(x=datos['year'])
plt.title('Datos atipicos año', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Datos atipicos año')

# %%
datos.dropna(subset=['selling_price'], inplace=True)

# %%
# conteo de datos atipicos selling_price

nivel_minimo =10000
nivel_maximo =500000
total_atipicos=((datos['selling_price']<nivel_minimo)|(datos['selling_price']<nivel_maximo)).sum()
print("el total de datos atipicos en cuanto al precio de venta de los coches es {}".format(total_atipicos))
# Out:
# el total de datos atipicos en cuanto al precio de venta de los coches es 4134

# %%
# identificación datos faltantes y atipicos en la casilla de precio de venta

plt.figure(figsize=(8, 4))
sns.boxplot(x=datos['selling_price'])
plt.title('Datos atipicos precio de venta', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Datos atipicos precio de venta')

# %%
# conteo de datos atipicos km_driven

nivel_minimo =100
nivel_maximo =400000
total_atipicos=((datos['km_driven']<nivel_minimo)|(datos['km_driven']<nivel_maximo)).sum()
print("el total de datos atipicos en cuanto al kilometraje de los coches es {}".format(total_atipicos))
# Out:
# el total de datos atipicos en cuanto al kilometraje de los coches es 7779

# %%
# identificación datos faltantes y atipicos en la casilla de kilometros recorridos

plt.figure(figsize=(8, 4))
sns.boxplot(x=datos['km_driven'])
plt.title('Datos atipicos kilometros recorridos', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Datos atipicos kilometros recorridos')

# %%
# conteo de datos atipicos seats

nivel_minimo =2
nivel_maximo =8
total_atipicos=((datos['seats']<nivel_minimo)|(datos['seats']<nivel_maximo)).sum()
print("el total de datos atipicos en cuanto a la cantidad de asientos de los coches es {}".format(total_atipicos))
# Out:
# el total de datos atipicos en cuanto a la cantidad de asientos de los coches es 7251

# %%
# identificación datos faltantes y atipicos en la casilla de cantidad de asientos

plt.figure(figsize=(8, 4))
sns.boxplot(x=datos['seats'])
plt.title('Datos atipicos asientos', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Datos atipicos asientos')

# %%
# revisión de datos atipicos y datos faltantes

datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7787 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7787 non-null   object
#  1   year           7787 non-null   float64
#  2   selling_price  7787 non-null   float64
#  3   km_driven      7787 non-null   float64
#  4   fuel           7787 non-null   object
#  5   seller_type    7787 non-null   object
#  6   transmission   7787 non-null   object
#  7   owner          7787 non-null   object
#  8   mileage        7566 non-null   object
#  9   engine         7566 non-null   object
#  10  max_power      7572 non-null   object
#  11  torque         7565 non-null   object
#  12  seats          7566 non-null   float64
# dtypes: float64(4), object(9)
# memory usage: 851.7+ KB

# %%
#3.Seleccionar las características más relevantes para entrenar el modelo utilizando selección de características.

# %%
#caracteristica a trabajar selling_price

datos['selling_price'].value_counts()
# Out:
# selling_price
# 300000.0     217
# 600000.0     212
# 550000.0     204
# 350000.0     202
# 450000.0     195
#             ...
# 654000.0       1
# 486000.0       1
# 1670000.0      1
# 7200000.0      1
# 746000.0       1
# Name: count, Length: 668, dtype: int64

# %%
datos[['selling_price']].head(50)
# Out:
#     selling_price
# 0        450000.0
# 1        370000.0
# 3        225000.0
# 5        440000.0
# 7         45000.0
# 8        350000.0
# 9        200000.0
# 10       500000.0
# 11        92000.0
# 12       280000.0
# 13       200000.0
# 14       180000.0
# 15       400000.0
# 16       778000.0
# 17       500000.0
# 18       150000.0
# 19       680000.0
# 20       174000.0
# 21       950000.0
# 22       525000.0
# 23       600000.0
# 24       500000.0
# 25       575000.0
# 26       275000.0
# 27       300000.0
# 28       220000.0
# 29       254999.0
# 30       670000.0
# 31        70000.0
# 32       150000.0
# 33       730000.0
# 34       650000.0
# 35       330000.0
# 36       366000.0
# 37      1149000.0
# 38       150000.0
# 39       425000.0
# 40       150000.0
# 41      2100000.0
# 42       925000.0
# 43       425000.0
# 44       675000.0
# 45       819999.0
# 46       390000.0
# 47      1500000.0
# 48       700000.0
# 49      1450000.0
# 50       425000.0
# 51      1090000.0
# ...

# %%
#4.Dividir el dataset en Train y Test para evaluar correctamente el modelo.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd

# porcentaje de datos para entrenamiento (train) = 75% , y para prueba (test) = 25%

# Imputar valores faltantes en la columna 'selling_price' usando la media
media_selling_price = datos['selling_price'].mean()
datos['selling_price'].fillna(media_selling_price, inplace=True)

# se crean las variables A y B para almacenar la información del entrenamiento

A = datos.drop(columns=['selling_price'])  # características
B = datos['selling_price']                 # variable objetivo

# la función train_test_split crea una división de un conjunto de datos en dos bloques uno de entrenamiento y el otro de prueba(train and test)
A_train, A_test, B_train, B_test = train_test_split(A, B, test_size=0.25, random_state=0)

# %%
print (A_train)
# Out:
#       km_driven    year
# 7179    83000.0  2010.0
# 6278    79000.0  2017.0
# 4060   110000.0  2015.0
# 2767    50000.0  2018.0
# 6557   110000.0  2015.0
# ...         ...     ...
# 5125    90000.0  2015.0
# 3389   120000.0  2012.0
# 1713    20000.0  2019.0
# 2704    10000.0  2017.0
# 2833    30000.0  2017.0
#
# [5840 rows x 2 columns]

# %%
print (B_train)
# Out:
# 7179     175000.0
# 6278     825000.0
# 4060     350000.0
# 2767     450000.0
# 6557     503000.0
#           ...
# 5125     610000.0
# 3389     287000.0
# 1713    3800000.0
# 2704    2199000.0
# 2833     850000.0
# Name: selling_price, Length: 5840, dtype: float64

# %%
# 5.Entrenar el modelo configurando los diferentes hiperparámetros

# %%
datos = datos[['selling_price', 'km_driven', 'year']]
X = datos.drop('selling_price',axis=1)
Y = datos['selling_price']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state= 0)

# %%
print (X)
# Out:
#       km_driven    year
# 0      145500.0  2014.0
# 1      120000.0  2014.0
# 3      127000.0  2010.0
# 5       45000.0  2017.0
# 7        5000.0  2001.0
# ...         ...     ...
# 8122    80000.0  2014.0
# 8123   110000.0  2013.0
# 8125   120000.0  2009.0
# 8126    25000.0  2013.0
# 8127    25000.0  2013.0
#
# [7787 rows x 2 columns]

# %%
print (Y)
# Out:
# 0       450000.0
# 1       370000.0
# 3       225000.0
# 5       440000.0
# 7        45000.0
#           ...
# 8122    475000.0
# 8123    320000.0
# 8125    382000.0
# 8126    290000.0
# 8127    290000.0
# Name: selling_price, Length: 7787, dtype: float64

# %%
modelo_regresion= LinearRegression()
modelo_regresion.fit (X_train, Y_train)
prediccion= modelo_regresion.predict(X_test)

# %%
print(prediccion)
# Out:
# [ 904079.49064216  796228.61811337  622561.82752338 ...  672239.50098515
#   344012.71729046 1081093.02787966]

# %%
#6.Evaluar el desempeño del modelo en el conjunto de Test con métricas como precisión, recall, F1-score, etc.

# %%
# Hacer predicciones en el conjunto de prueba
predicciones = modelo_regresion.predict(X_test)

# Calcular métricas de rendimiento
mae = mean_absolute_error(Y_test, predicciones)
mse = mean_squared_error(Y_test, predicciones)
rmse = mean_squared_error(Y_test, predicciones, squared=False)
r2 = r2_score(Y_test, predicciones)

print("Error absoluto medio:", mae)
print("Error cuadrático medio:", mse)
print("Raíz del error cuadrático medio:", rmse)
print("Coeficiente de determinación (R^2):", r2)

# Visualizar las predicciones
plt.scatter(Y_test, predicciones)
plt.xlabel("Valores reales")
plt.ylabel("Predicciones")
plt.title("Predicciones vs Valores reales")
plt.show()
# Out:
# Error absoluto medio: 409011.8652330448
# Error cuadrático medio: 653865002539.3842
# Raíz del error cuadrático medio: 808619.1950104722
# Coeficiente de determinación (R^2): 0.16319101397301405

# %%
#7.Realizar las diferentes gráficas que permitan visualizar los resultados del modelo.

# %%
# Diagrama de dispersión de valores reales vs. predichos
plt.figure(figsize=(10, 6))
sns.scatterplot(x=Y_test, y=prediccion)
plt.xlabel('Precio real')
plt.ylabel('Precio predicho')
plt.title('Diagrama de dispersión de valores reales vs. predichos')
plt.show()
